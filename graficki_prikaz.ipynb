# %%
#@title
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
organisms=["Bacillus_subtilis", "\nCryptococcus_neoformans", "Enterococcus_faecalis", "\nEscherichia_coli", "Lactobacillus_fermentum", "\nListeria_monocytogenes", "Pseudomonas_aeruginosa", "\nSaccharomyces_cerevisiae", "Salmonella_enterica", "\nStaphylococcus_aureus"]
data1_non_chimeric=[3828715199,1030354603,3156058258,3037169632,4253200055,3707314747,2436628936,573634341,3032976558,3606590636]
data2_chimeric=[44002170,367468960,48267597,31411366,137098372,43163002,30568549,42048759,55905425,49564853]
data_all=[3872717369,1397823563,3204325855,3068580998,4390298427,3750477749,2467197485,615683100,3088881983,3656155489]
bar_width = 0.3
fig, ax = plt.subplots(figsize=(15, 5))
ax.bar(np.arange(len(organisms))-bar_width/2, data1_non_chimeric, width=bar_width, label='non-chimeric')
ax.bar(np.arange(len(organisms))-bar_width/2, data2_chimeric, bottom=data1_non_chimeric, width=bar_width, label='chimeric')
#ax.bar(np.arange(len(organisms))+bar_width/2, data_all, width=bar_width, label='all reads')
ax.set_xticks(np.arange(len(organisms)))
ax.set_xticklabels(organisms)
ax.set_xlabel('Organisms')
ax.set_title('Total values')
ax.legend()
plt.show()

# %% [markdown]
# Slika prikazuje stupčasti graf na kojem vidimo koliko ukupno ima kimernih i nekimernih očitanja, tj. koliki je zbroj duljina svih sekvenci readova za pojedini organizam. Vidimo da plavi dio nekimernih i narančasti dio kimernih podataka zajedno daju sveukupni zeleni dio. Iz toga se može zaključiti da je udio kimernih očitanja malen. Za bolji prikaz postotaka pogledajmo sljedeći graf.

# %%
#@title
x=["Bacillus_subtilis", "\nCryptococcus_neoformans", "Enterococcus_faecalis", "\nEscherichia_coli", "Lactobacillus_fermentum", "\nListeria_monocytogenes", "Pseudomonas_aeruginosa", "\nSaccharomyces_cerevisiae", "Salmonella_enterica", "\nStaphylococcus_aureus"]
data1=[98.86,73.71,98.49,98.98,96.88,98.85,98.76,93.17,98.19,98.64]
data2=[1.14,26.29,1.51,1.02,3.12,1.15,1.24,6.83,1.81,1.36]
fig, ax = plt.subplots(figsize=(15, 5))
line1, = plt.plot(x,data1,label='non-chimeric', linestyle='-', marker='o')
line2, = plt.plot(x,data2,label='chimeric', linestyle='-', marker='o')
plt.title("Percentage values")
plt.ylabel('%')
plt.xlabel('Organisms')
plt.legend(handles=[line1, line2], loc='center')
plt.grid(visible=True, which='major', color='black', alpha=0.6, linestyle='-', lw=0.6)
plt.minorticks_on()
plt.grid(visible=True, which='minor', color='gray', alpha=0.5, ls=':', lw=0.5)
plt.show()

# %% [markdown]
# Na ovom linijskom prikazu bolje iščitavamo da kimerna očitanja kod skoro svih organizama čine malo više od 1% svih podataka. Izuzetak je Cryptococcus_neoformans koji ima 26.29% kimernih očitanja i Saccharomyces_cerevisiae koji ima 6.83% kimernih očitanja.

# %%
organisms=["Bacillus_subtilis", "\nCryptococcus_neoformans", "Enterococcus_faecalis", "\nEscherichia_coli", "Lactobacillus_fermentum", "\nListeria_monocytogenes", "Pseudomonas_aeruginosa", "\nSaccharomyces_cerevisiae", "Salmonella_enterica", "\nStaphylococcus_aureus"]
data1_non_chimeric=[595314, 232532, 532937, 254723, 2138551, 588647, 200866, 98190, 331898, 554013]
data2_chimeric=[2064, 57116, 2568, 1060, 23371, 2564, 1084, 2315, 2096, 2848]
data_all=[597378, 289648, 535505, 255783, 2161922, 591211, 201950, 100505, 333994, 556861]
bar_width = 0.3
fig, ax = plt.subplots(figsize=(15, 5))
ax.bar(np.arange(len(organisms))-bar_width/2, data1_non_chimeric, width=bar_width, label='non-chimeric')
ax.bar(np.arange(len(organisms))-bar_width/2, data2_chimeric, bottom=data1_non_chimeric, width=bar_width, label='chimeric')
#ax.bar(np.arange(len(organisms))+bar_width/2, data_all, width=bar_width, label='all reads')
ax.set_xticks(np.arange(len(organisms)))
ax.set_xticklabels(organisms)
ax.set_xlabel('Organisms')
ax.set_title('Quantity values')
ax.legend()
plt.show()

# %% [markdown]
# Ovaj stupčasti graf prikazuje brojnost sekvenci za svaku vrstu readova (nekimerna, kimerna i sve zajedno). Kod većine organizama ne možemo niti primijetiti narančasti dio koliko je malen naspram broja nekimernih očitanja.

# %%
#@title
x=["Bacillus_subtilis", "\nCryptococcus_neoformans", "Enterococcus_faecalis", "\nEscherichia_coli", "Lactobacillus_fermentum", "\nListeria_monocytogenes", "Pseudomonas_aeruginosa", "\nSaccharomyces_cerevisiae", "Salmonella_enterica", "\nStaphylococcus_aureus"]
data1=[99.65, 80.28, 99.52, 99.59, 98.92, 99.57, 99.46, 97.7, 99.37, 99.49]
data2=[0.35, 19.72, 0.48, 0.41, 1.08, 0.43, 0.54, 2.3, 0.63, 0.51]
fig, ax = plt.subplots(figsize=(15, 5))
line1, = plt.plot(x,data1,label='non-chimeric', linestyle='-', marker='o')
line2, = plt.plot(x,data2,label='chimeric', linestyle='-', marker='o')
plt.title("Percentage values")
plt.ylabel('%')
plt.xlabel('Organisms')
plt.legend(handles=[line1, line2], loc='center')
plt.grid(visible=True, which='major', color='black', alpha=0.6, linestyle='-', lw=0.6)
plt.minorticks_on()
plt.grid(visible=True, which='minor', color='gray', alpha=0.5, ls=':', lw=0.5)
plt.show()

# %% [markdown]
# Cryptococcus_neoformans_chimeric čini 19.72% broja sekvenci, dok Saccharomyces_cerevisiae_chimeric čini svega 2.3% broja sekvenci. Brojnost drugih organizama kimernih sekvenci manja je od 1%.

# %%
#@title
x=["Bacillus_subtilis", "\nCryptococcus_neoformans", "Enterococcus_faecalis", "\nEscherichia_coli", "Lactobacillus_fermentum", "\nListeria_monocytogenes", "Pseudomonas_aeruginosa", "\nSaccharomyces_cerevisiae", "Salmonella_enterica", "\nStaphylococcus_aureus"]
data1=[6482.859042,4825.938943,5983.745913,11996.813698,2030.738587,6343.721191,12216.872914,6125.895229,9248.315787,6565.651911]
data2=[21318.880814,6433.730653,18795.793224,29633.364151,5866.174832,16834.244150,28199.768450,18163.610799,26672.435592,17403.389396]
data3=[6431.421399,4431.022840,5922.010027,11923.421254,1988.823299,6298.027081,12130.619099,5842.085151,9138.279104,6509.938640]
fig, ax = plt.subplots(figsize=(15, 5))
line3, = plt.plot(x,data3,label='non-chimeric',linestyle='-', marker='o')
line2, = plt.plot(x,data2,label='chimeric',linestyle='-', marker='o')
line1, = plt.plot(x,data1,label='all reads', linestyle='-', marker='o')
plt.title("Average values")
plt.xlabel('Organisms')
plt.legend(handles=[line3,line2,line1], loc='upper right')
plt.grid(visible=True, which='major', color='black', alpha=0.6, linestyle='-', lw=0.6)
plt.minorticks_on()
plt.grid(visible=True, which='minor', color='gray', alpha=0.5, ls=':', lw=0.5)
plt.show()

# %% [markdown]
# Prosjeci duljina sekvenci kimernih očitanja su veći od prosjeka duljina svih sekvenci za sve organizme. Također, plava linija i zelena linija se gotovo poklapaju, što znači da su im prosječne vrijednosti duljina sekvenci približno jednake.

# %%
data_all = [436, 2570.0, 4489, 7188.0, 219696]
data_chimeric = [1239, 7104.0, 11595, 24303.5, 219696]
data_nonchimeric = [436, 2565.0, 4478, 7163.0, 154354]
data=[data_all, data_chimeric, data_nonchimeric]
fig, ax = plt.subplots(figsize=(15, 5))
ax.boxplot(data, showfliers=False, vert=False)
ax.set_xlabel('Length')
ax.set_ylabel('Bacillus_subtilis')
ax.set_yticklabels(['data_all', 'data_chimeric', 'data_nonchimeric'])
ax.set_title('Box Plot')
plt.show()

# %% [markdown]
# Kutijasti dijagram ili box-plot je graf koji se sastoji od pravokutnika koji prikazuje podatke od prvog do trećeg kvartila. Crta unutar samog pravokutnika označava medijan. Horizontalna linija van pravokutnika pruža se sve do minimalne očitane vrijednosti duljine sekvence. Za organizam Bacillus_subtilis prosječna duljina svih sekvenci iznosi 6482.86, a prvi kvartil nalazi se u intervalu 436-2570. Od toga je 447 kimernih sekvenci manje od prosjeka, a 42 manje od gornje granice prvog kvartila.

# %%
data_all = [365, 2702.0, 4374, 6407.0, 110897]
data_chimeric = [885, 4261.0, 5934.5, 7945.0, 110897]
data_nonchimeric = [365, 2416.0, 3989, 5941.0, 67214]
data=[data_all, data_chimeric, data_nonchimeric]
fig, ax = plt.subplots(figsize=(15, 5))
ax.boxplot(data, showfliers=False, vert=False)
ax.set_xlabel('Length')
ax.set_ylabel('Cryptococcus_neoformans')
ax.set_yticklabels(['data_all', 'data_chimeric', 'data_nonchimeric'])
ax.set_title('Box Plot')
plt.show()

# %% [markdown]
# Za organizam Cryptococcus_neoformans prosječna duljina svih sekvenci iznosi 4825.94, a prvi kvartil nalazi se u intervalu 365-2702. Od toga je 19026 kimernih sekvenci manje od prosjeka, a 3563 manje od gornje granice prvog kvartila.

# %%
data_all = [472, 2060.0, 3955, 6800.0, 185023]
data_chimeric = [1230, 6297.75, 11115, 24190.75, 185023]
data_nonchimeric = [472, 2053.0, 3939, 6760.0, 148963]
data=[data_all, data_chimeric, data_nonchimeric]
fig, ax = plt.subplots(figsize=(15, 5))
ax.boxplot(data, showfliers=False, vert=False)
ax.set_xlabel('Length')
ax.set_ylabel('Enterococcus_faecalis')
ax.set_yticklabels(['data_all', 'data_chimeric', 'data_nonchimeric'])
ax.set_title('Box Plot')
plt.show()

# %% [markdown]
# Za organizam Enterococcus_faecalis prosječna duljina svih sekvenci iznosi 5983.75, a prvi kvartil nalazi se u intervalu 472-2060. Od toga je 585 kimernih sekvenci manje od prosjeka, a 36 manje od gornje granice prvog kvartila.

# %%
data_all = [439, 3128.0, 7165, 16857.0, 129402]
data_chimeric = [1268, 12628.5, 24050, 41146.25, 129402]
data_nonchimeric = [439, 3117.0, 7127, 16752.0, 125209]
data=[data_all, data_chimeric, data_nonchimeric]
fig, ax = plt.subplots(figsize=(15, 5))
ax.boxplot(data, showfliers=False, vert=False)
ax.set_xlabel('Length')
ax.set_ylabel('Escherichia_coli')
ax.set_yticklabels(['data_all', 'data_chimeric', 'data_nonchimeric'])
ax.set_title('Box Plot')
plt.show()

# %% [markdown]
# Za organizam Escherichia_coli prosječna duljina svih sekvenci iznosi 11996.81, a prvi kvartil nalazi se u intervalu 439-3128. Od toga je 250 kimernih sekvenci manje od prosjeka, a 21 manje od gornje granice prvog kvartila.

# %%
data_all = [390, 912.0, 1213, 1945.0, 288530]
data_chimeric = [1064, 2171.0, 3227, 6100.5, 230752]
data_nonchimeric = [390, 909.0, 1204, 1908.0, 288530]
data=[data_all, data_chimeric, data_nonchimeric]
fig, ax = plt.subplots(figsize=(15, 5))
ax.boxplot(data, showfliers=False, vert=False)
ax.set_xlabel('Length')
ax.set_ylabel('Lactobacillus_fermentum')
ax.set_yticklabels(['data_all', 'data_chimeric', 'data_nonchimeric'])
ax.set_title('Box Plot')
plt.show()

# %% [markdown]
# Za organizam Lactobacillus_fermentum prosječna duljina svih sekvenci iznosi 2030.74, a prvi kvartil nalazi se u intervalu 390-912. Od toga je 4670 kimernih sekvenci manje od prosjeka, a 0 manje od gornje granice prvog kvartila.

# %%
data_all = [429, 2604.0, 4446, 6927.0, 219919]
data_chimeric = [1325, 6173.0, 9457.5, 17554.75, 219919]
data_nonchimeric = [429, 2597.0, 4433, 6900.0, 148443]
data=[data_all, data_chimeric, data_nonchimeric]
fig, ax = plt.subplots(figsize=(15, 5))
ax.boxplot(data, showfliers=False, vert=False)
ax.set_xlabel('Length')
ax.set_ylabel('Listeria_monocytogenes')
ax.set_yticklabels(['data_all', 'data_chimeric', 'data_nonchimeric'])
ax.set_title('Box Plot')
plt.show()

# %% [markdown]
# Za organizam Listeria_monocytogenes prosječna duljina svih sekvenci iznosi 6343.72, a prvi kvartil nalazi se u intervalu 429-2604. Od toga je 677 kimernih sekvenci manje od prosjeka, a 53 manje od gornje granice prvog kvartila.

# %%
data_all = [462, 3218.0, 7410, 17312.0, 130105]
data_chimeric = [1321, 12093.5, 23082, 39879.0, 130105]
data_nonchimeric = [462, 3204.0, 7361, 17180.75, 108707]
data=[data_all, data_chimeric, data_nonchimeric]
fig, ax = plt.subplots(figsize=(15, 5))
ax.boxplot(data, showfliers=False, vert=False)
ax.set_xlabel('Length')
ax.set_ylabel('Pseudomonas_aeruginosa')
ax.set_yticklabels(['data_all', 'data_chimeric', 'data_nonchimeric'])
ax.set_title('Box Plot')
plt.show()

# %% [markdown]
# Za organizam Pseudomonas_aeruginosa prosječna duljina svih sekvenci iznosi 12216.87, a prvi kvartil nalazi se u intervalu 462-3218. Od toga je 276 kimernih sekvenci manje od prosjeka, a 19 manje od gornje granice prvog kvartila.

# %%
data_all = [475, 2756.0, 4491, 6727.0, 215466]
data_chimeric = [1097, 6885.5, 10010, 22055.5, 215466]
data_nonchimeric = [475, 2718.0, 4419.5, 6585.0, 131317]
data=[data_all, data_chimeric, data_nonchimeric]
fig, ax = plt.subplots(figsize=(15, 5))
ax.boxplot(data, showfliers=False, vert=False)
ax.set_xlabel('Length')
ax.set_ylabel('Saccharomyces_cerevisiae')
ax.set_yticklabels(['data_all', 'data_chimeric', 'data_nonchimeric'])
ax.set_title('Box Plot')
plt.show()

# %% [markdown]
# Za organizam Saccharomyces_cerevisiae prosječna duljina svih sekvenci iznosi 6125.90, a prvi kvartil nalazi se u intervalu 475-2756. Od toga je 410 kimernih sekvenci manje od prosjeka, a 39 manje od gornje granice prvog kvartila.

# %%
data_all = [464, 1504.0, 4151, 12299.0, 123557]
data_chimeric = [1281, 11424.5, 23390.5, 36774.75, 123557]
data_nonchimeric = [464, 1496.0, 4107, 12122.0, 103220]
data=[data_all, data_chimeric, data_nonchimeric]
fig, ax = plt.subplots(figsize=(15, 5))
ax.boxplot(data, showfliers=False, vert=False)
ax.set_xlabel('Length')
ax.set_ylabel('Salmonella_enterica')
ax.set_yticklabels(['data_all', 'data_chimeric', 'data_nonchimeric'])
ax.set_title('Box Plot')
plt.show()

# %% [markdown]
# Za organizam Salmonella_enterica prosječna duljina svih sekvenci iznosi 9248.32, a prvi kvartil nalazi se u intervalu 464-1504. Od toga je 406 kimernih sekvenci manje od prosjeka, a 6 manje od gornje granice prvog kvartila.

# %%
data_all = [432, 2196.0, 4260, 7076.0, 274400]
data_chimeric = [1184, 3835.0, 8217, 18651.0, 274400]
data_nonchimeric = [432, 2188.0, 4250, 7050.0, 193034]
data=[data_all, data_chimeric, data_nonchimeric]
fig, ax = plt.subplots(figsize=(15, 5))
ax.boxplot(data, showfliers=False, vert=False)
ax.set_xlabel('Length')
ax.set_ylabel('Staphylococcus_aureus')
ax.set_yticklabels(['data_all', 'data_chimeric', 'data_nonchimeric'])
ax.set_title('Box Plot')
plt.show()

# %% [markdown]
# Za organizam Staphylococcus_aureus prosječna duljina svih sekvenci iznosi 6565.65, a prvi kvartil nalazi se u intervalu 432-2196. Od toga je 1172 kimernih sekvenci manje od prosjeka, a 118 manje od gornje granice prvog kvartila.
